# %%
import pandas as pd
import numpy as np

# %%
house_file = "data_original/district_overall_2018.csv"
house_df_original = pd.read_csv(house_file)
house_df_original.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic  \
# 0  2018  California       CA           6         93        71
# 1  2018  California       CA           6         93        71
# 2  2018  California       CA           6         93        71
# 3  2018  California       CA           6         93        71
# 4  2018  California       CA           6         93        71
#
#                 office     district stage  special        candidate  \
# 0  U.S. Representative   District 1   gen    False    Audrey Denney
# 1  U.S. Representative   District 1   gen    False    Doug La Malfa
# 2  U.S. Representative  District 10   gen    False      Jeff Denham
# 3  U.S. Representative  District 10   gen    False      Josh Harder
# 4  U.S. Representative  District 11   gen    False  John Fitzgerald
#
#         party  writein   mode  candidatevotes  totalvotes  unofficial  \
# 0    democrat    False  total          263096      583188       False
# 1  republican    False  total          320092      583188       False
# 2  republican    False  total          211910      443800       False
# 3    democrat    False  total          231890      443800       False
# 4  republican    False  total          142624      551362       False
#
#     version
# 0  20190131
# 1  20190131
# 2  20190131
# 3  20190131
# 4  20190131

# %%
# Make a copy 
house_df = house_df_original
house_df.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic  \
# 0  2018  California       CA           6         93        71
# 1  2018  California       CA           6         93        71
# 2  2018  California       CA           6         93        71
# 3  2018  California       CA           6         93        71
# 4  2018  California       CA           6         93        71
#
#                 office     district stage  special        candidate  \
# 0  U.S. Representative   District 1   gen    False    Audrey Denney
# 1  U.S. Representative   District 1   gen    False    Doug La Malfa
# 2  U.S. Representative  District 10   gen    False      Jeff Denham
# 3  U.S. Representative  District 10   gen    False      Josh Harder
# 4  U.S. Representative  District 11   gen    False  John Fitzgerald
#
#         party  writein   mode  candidatevotes  totalvotes  unofficial  \
# 0    democrat    False  total          263096      583188       False
# 1  republican    False  total          320092      583188       False
# 2  republican    False  total          211910      443800       False
# 3    democrat    False  total          231890      443800       False
# 4  republican    False  total          142624      551362       False
#
#     version
# 0  20190131
# 1  20190131
# 2  20190131
# 3  20190131
# 4  20190131

# %%
# Drop the columns that we don't need
house_df = house_df.drop(columns=["year", "state_fips", "state_cen", "state_ic", "office", "stage", "writein",
                                  "mode", "unofficial", "version"])
house_df.head()
# Out:
#         state state_po     district  special        candidate       party  \
# 0  California       CA   District 1    False    Audrey Denney    democrat
# 1  California       CA   District 1    False    Doug La Malfa  republican
# 2  California       CA  District 10    False      Jeff Denham  republican
# 3  California       CA  District 10    False      Josh Harder    democrat
# 4  California       CA  District 11    False  John Fitzgerald  republican
#
#    candidatevotes  totalvotes
# 0          263096      583188
# 1          320092      583188
# 2          211910      443800
# 3          231890      443800
# 4          142624      551362

# %%
# Rename columns
house_df = house_df.rename(columns={"state": "State", "state_po": "State Abbreviation", "district": "District Number",
                                    "special": "Special Election", "candidate": "Candidate", "party": "Party",
                                    "candidatevotes": "Candidate Votes", "totalvotes": "Total Votes"})
house_df.head()
# Out:
#         State State Abbreviation District Number  Special Election  \
# 0  California                 CA      District 1             False
# 1  California                 CA      District 1             False
# 2  California                 CA     District 10             False
# 3  California                 CA     District 10             False
# 4  California                 CA     District 11             False
#
#          Candidate       Party  Candidate Votes  Total Votes
# 0    Audrey Denney    democrat           263096       583188
# 1    Doug La Malfa  republican           320092       583188
# 2      Jeff Denham  republican           211910       443800
# 3      Josh Harder    democrat           231890       443800
# 4  John Fitzgerald  republican           142624       551362

# %%
# Clean up Congressional District column
house_df["District Number"] = house_df["District Number"].str.split(' ', expand=False).str[1]

# %%
# Create new column with unique identifier for state-district
house_df["Congressional District"] = house_df["State Abbreviation"] + "-" + house_df["District Number"]
house_df.head()
# Out:
#         State State Abbreviation District Number  Special Election  \
# 0  California                 CA               1             False
# 1  California                 CA               1             False
# 2  California                 CA              10             False
# 3  California                 CA              10             False
# 4  California                 CA              11             False
#
#          Candidate       Party  Candidate Votes  Total Votes  \
# 0    Audrey Denney    democrat           263096       583188
# 1    Doug La Malfa  republican           320092       583188
# 2      Jeff Denham  republican           211910       443800
# 3      Josh Harder    democrat           231890       443800
# 4  John Fitzgerald  republican           142624       551362
#
#   Congressional District
# 0                   CA-1
# 1                   CA-1
# 2                  CA-10
# 3                  CA-10
# 4                  CA-11

# %%
# Create a new column with the % of the vote that the candidate received
house_df["Candidate Percent"] = house_df["Candidate Votes"] / house_df["Total Votes"]
house_df.head()
# Out:
#         State State Abbreviation District Number  Special Election  \
# 0  California                 CA               1             False
# 1  California                 CA               1             False
# 2  California                 CA              10             False
# 3  California                 CA              10             False
# 4  California                 CA              11             False
#
#          Candidate       Party  Candidate Votes  Total Votes  \
# 0    Audrey Denney    democrat           263096       583188
# 1    Doug La Malfa  republican           320092       583188
# 2      Jeff Denham  republican           211910       443800
# 3      Josh Harder    democrat           231890       443800
# 4  John Fitzgerald  republican           142624       551362
#
#   Congressional District  Candidate Percent
# 0                   CA-1           0.451134
# 1                   CA-1           0.548866
# 2                  CA-10           0.477490
# 3                  CA-10           0.522510
# 4                  CA-11           0.258676

# %%
# Reorder columns
house_df = house_df[["Congressional District", "State", "State Abbreviation", "District Number", "Special Election",
                                 "Candidate", "Party", "Candidate Votes", "Total Votes", "Candidate Percent"]]
house_df.head()
# Out:
#   Congressional District       State State Abbreviation District Number  \
# 0                   CA-1  California                 CA               1
# 1                   CA-1  California                 CA               1
# 2                  CA-10  California                 CA              10
# 3                  CA-10  California                 CA              10
# 4                  CA-11  California                 CA              11
#
#    Special Election        Candidate       Party  Candidate Votes  \
# 0             False    Audrey Denney    democrat           263096
# 1             False    Doug La Malfa  republican           320092
# 2             False      Jeff Denham  republican           211910
# 3             False      Josh Harder    democrat           231890
# 4             False  John Fitzgerald  republican           142624
#
#    Total Votes  Candidate Percent
# 0       583188           0.451134
# 1       583188           0.548866
# 2       443800           0.477490
# 3       443800           0.522510
# 4       551362           0.258676

# %%
# Export the cleaned data
house_df.to_csv("data_clean/district_overall_2018_clean.csv", index=False)
