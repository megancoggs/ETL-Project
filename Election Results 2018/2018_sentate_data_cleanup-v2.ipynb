# %%
import pandas as pd
import numpy as np

# %%
# Read in the csv file and view the DataFrame
senate_file = "data_original/senate_overall_2018.csv"
senate_df_original = pd.read_csv(senate_file)
senate_df_original.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic     office  \
# 0  2018     Arizona       AZ           4         86        61  US Senate
# 1  2018     Arizona       AZ           4         86        61  US Senate
# 2  2018     Arizona       AZ           4         86        61  US Senate
# 3  2018     Arizona       AZ           4         86        61  US Senate
# 4  2018  California       CA           6         93        71  US Senate
#
#     district stage  special         candidate       party  writein   mode  \
# 0  statewide   gen    False    Martha McSally  republican    False  total
# 1  statewide   gen    False    Kyrsten Sinema    democrat    False  total
# 2  statewide   gen    False      Angela Green       green    False  total
# 3  statewide   gen    False               NaN         NaN     True  total
# 4  statewide   gen    False  Dianne Feinstein    democrat    False  total
#
#    candidatevotes  totalvotes  unofficial   version
# 0         1135200     2384308       False  20190110
# 1         1191100     2384308       False  20190110
# 2           57442     2384308       False  20190110
# 3             566     2384308       False  20190110
# 4         6019422    11113364       False  20190110

# %%
# Make a copy 
senate_df = senate_df_original
senate_df.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic     office  \
# 0  2018     Arizona       AZ           4         86        61  US Senate
# 1  2018     Arizona       AZ           4         86        61  US Senate
# 2  2018     Arizona       AZ           4         86        61  US Senate
# 3  2018     Arizona       AZ           4         86        61  US Senate
# 4  2018  California       CA           6         93        71  US Senate
#
#     district stage  special         candidate       party  writein   mode  \
# 0  statewide   gen    False    Martha McSally  republican    False  total
# 1  statewide   gen    False    Kyrsten Sinema    democrat    False  total
# 2  statewide   gen    False      Angela Green       green    False  total
# 3  statewide   gen    False               NaN         NaN     True  total
# 4  statewide   gen    False  Dianne Feinstein    democrat    False  total
#
#    candidatevotes  totalvotes  unofficial   version
# 0         1135200     2384308       False  20190110
# 1         1191100     2384308       False  20190110
# 2           57442     2384308       False  20190110
# 3             566     2384308       False  20190110
# 4         6019422    11113364       False  20190110

# %%
# Drop the columns that we don't need
senate_df = senate_df.drop(columns=["year", "state_fips", "state_cen", "state_ic", "office", "district", "stage", "writein",
                                  "mode", "unofficial", "version"])
senate_df.head()
# Out:
#         state state_po  special         candidate       party  candidatevotes  \
# 0     Arizona       AZ    False    Martha McSally  republican         1135200
# 1     Arizona       AZ    False    Kyrsten Sinema    democrat         1191100
# 2     Arizona       AZ    False      Angela Green       green           57442
# 3     Arizona       AZ    False               NaN         NaN             566
# 4  California       CA    False  Dianne Feinstein    democrat         6019422
#
#    totalvotes
# 0     2384308
# 1     2384308
# 2     2384308
# 3     2384308
# 4    11113364

# %%
# Rename columns
senate_df = senate_df.rename(columns={"state": "State", "state_po": "State Abbreviation", "special": "Special Election",
                                    "candidate": "Candidate", "party": "Party", "candidatevotes": "Candidate Votes",
                                    "totalvotes": "Total Votes"})
senate_df.head()
# Out:
#         State State Abbreviation  Special Election         Candidate  \
# 0     Arizona                 AZ             False    Martha McSally
# 1     Arizona                 AZ             False    Kyrsten Sinema
# 2     Arizona                 AZ             False      Angela Green
# 3     Arizona                 AZ             False               NaN
# 4  California                 CA             False  Dianne Feinstein
#
#         Party  Candidate Votes  Total Votes
# 0  republican          1135200      2384308
# 1    democrat          1191100      2384308
# 2       green            57442      2384308
# 3         NaN              566      2384308
# 4    democrat          6019422     11113364

# %%
# Create a new column with the % of the vote that the candidate received
senate_df["Candidate Percent"] = senate_df["Candidate Votes"] / senate_df["Total Votes"]
senate_df.head()
# Out:
#         State State Abbreviation  Special Election         Candidate  \
# 0     Arizona                 AZ             False    Martha McSally
# 1     Arizona                 AZ             False    Kyrsten Sinema
# 2     Arizona                 AZ             False      Angela Green
# 3     Arizona                 AZ             False               NaN
# 4  California                 CA             False  Dianne Feinstein
#
#         Party  Candidate Votes  Total Votes  Candidate Percent
# 0  republican          1135200      2384308           0.476113
# 1    democrat          1191100      2384308           0.499558
# 2       green            57442      2384308           0.024092
# 3         NaN              566      2384308           0.000237
# 4    democrat          6019422     11113364           0.541638

# %%
# Change all parties other than democrat and republican to "other"
senate_df.loc[(senate_df["Party"] != "republican") & (senate_df["Party"] != "democrat"), "Party"] = "other"
senate_df.loc[senate_df["Party"] == "other"]
# Out:
#              State State Abbreviation  Special Election             Candidate  \
# 2          Arizona                 AZ             False          Angela Green
# 3          Arizona                 AZ             False                   NaN
# 8      Connecticut                 CT             False  Christopher S Murphy
# 9      Connecticut                 CT             False          Richard Lion
# 10     Connecticut                 CT             False          Jeff Russell
# ..             ...                ...               ...                   ...
# 139       Virginia                 VA             False                   NaN
# 144  West Virginia                 WV             False          Rusty Hollen
# 147      Wisconsin                 WI             False                   NaN
# 150        Wyoming                 WY             False        Joseph Porambo
# 151        Wyoming                 WY             False                   NaN
#
#      Party  Candidate Votes  Total Votes  Candidate Percent
# 2    other            57442      2384308           0.024092
# 3    other              566      2384308           0.000237
# 8    other            37894      1386840           0.027324
# 9    other             8838      1386840           0.006373
# 10   other             6618      1386840           0.004772
# ..     ...              ...          ...                ...
# 139  other             5125      3351373           0.001529
# 144  other            24231       582911           0.041569
# 147  other               42      2657841           0.000016
# 150  other             5658       203420           0.027814
# 151  other              325       203420           0.001598
#
# [86 rows x 8 columns]

# %%
# View final DataFrame
senate_df.head()
# Out:
#         State State Abbreviation  Special Election         Candidate  \
# 0     Arizona                 AZ             False    Martha McSally
# 1     Arizona                 AZ             False    Kyrsten Sinema
# 2     Arizona                 AZ             False      Angela Green
# 3     Arizona                 AZ             False               NaN
# 4  California                 CA             False  Dianne Feinstein
#
#         Party  Candidate Votes  Total Votes  Candidate Percent
# 0  republican          1135200      2384308           0.476113
# 1    democrat          1191100      2384308           0.499558
# 2       other            57442      2384308           0.024092
# 3       other              566      2384308           0.000237
# 4    democrat          6019422     11113364           0.541638

# %%
# Export the cleaned data
senate_df.to_csv("data_clean/senate_overall_2018_clean.csv")
