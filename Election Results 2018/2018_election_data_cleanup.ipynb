# %%
import pandas as pd
import numpy as np

# %%
house_file = "Data/district_overall_2018.csv"
house_df_original = pd.read_csv(house_file)
house_df_original.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic  \
# 0  2018  California       CA           6         93        71
# 1  2018  California       CA           6         93        71
# 2  2018  California       CA           6         93        71
# 3  2018  California       CA           6         93        71
# 4  2018  California       CA           6         93        71
#
#                 office     district stage  special        candidate  \
# 0  U.S. Representative   District 1   gen    False    Audrey Denney
# 1  U.S. Representative   District 1   gen    False    Doug La Malfa
# 2  U.S. Representative  District 10   gen    False      Jeff Denham
# 3  U.S. Representative  District 10   gen    False      Josh Harder
# 4  U.S. Representative  District 11   gen    False  John Fitzgerald
#
#         party  writein   mode  candidatevotes  totalvotes  unofficial  \
# 0    democrat    False  total          263096      583188       False
# 1  republican    False  total          320092      583188       False
# 2  republican    False  total          211910      443800       False
# 3    democrat    False  total          231890      443800       False
# 4  republican    False  total          142624      551362       False
#
#     version
# 0  20190131
# 1  20190131
# 2  20190131
# 3  20190131
# 4  20190131

# %%
# Make a copy 
house_df = house_df_original
house_df.head()
# Out:
#    year       state state_po  state_fips  state_cen  state_ic  \
# 0  2018  California       CA           6         93        71
# 1  2018  California       CA           6         93        71
# 2  2018  California       CA           6         93        71
# 3  2018  California       CA           6         93        71
# 4  2018  California       CA           6         93        71
#
#                 office     district stage  special        candidate  \
# 0  U.S. Representative   District 1   gen    False    Audrey Denney
# 1  U.S. Representative   District 1   gen    False    Doug La Malfa
# 2  U.S. Representative  District 10   gen    False      Jeff Denham
# 3  U.S. Representative  District 10   gen    False      Josh Harder
# 4  U.S. Representative  District 11   gen    False  John Fitzgerald
#
#         party  writein   mode  candidatevotes  totalvotes  unofficial  \
# 0    democrat    False  total          263096      583188       False
# 1  republican    False  total          320092      583188       False
# 2  republican    False  total          211910      443800       False
# 3    democrat    False  total          231890      443800       False
# 4  republican    False  total          142624      551362       False
#
#     version
# 0  20190131
# 1  20190131
# 2  20190131
# 3  20190131
# 4  20190131

# %%
# Drop the columns that we don't need
house_df = house_df.drop(columns=["year", "state_po", "state_fips", "state_cen", "state_ic", "office", "stage", "special", "writein",
                                  "mode", "unofficial", "version"])
house_df.head()
# Out:
#         state     district        candidate       party  candidatevotes  \
# 0  California   District 1    Audrey Denney    democrat          263096
# 1  California   District 1    Doug La Malfa  republican          320092
# 2  California  District 10      Jeff Denham  republican          211910
# 3  California  District 10      Josh Harder    democrat          231890
# 4  California  District 11  John Fitzgerald  republican          142624
#
#    totalvotes
# 0      583188
# 1      583188
# 2      443800
# 3      443800
# 4      551362

# %%
# Rename columns
house_df = house_df.rename(columns={"state": "State", "district": "District Number",
                                    "candidate": "Candidate", "party": "Party",
                                    "candidatevotes": "Candidate Votes",
                                    "totalvotes": "Total Votes"
                                   })
house_df.head()
# Out:
#         State District Number        Candidate       Party  Candidate Votes  \
# 0  California      District 1    Audrey Denney    democrat           263096
# 1  California      District 1    Doug La Malfa  republican           320092
# 2  California     District 10      Jeff Denham  republican           211910
# 3  California     District 10      Josh Harder    democrat           231890
# 4  California     District 11  John Fitzgerald  republican           142624
#
#    Total Votes
# 0       583188
# 1       583188
# 2       443800
# 3       443800
# 4       551362

# %%
# Clean up Congressional District column
house_df["District Number"] = house_df["District Number"].str.split(' ', expand=False).str[1]
house_df.head()
# Out:
#         State District Number        Candidate       Party  Candidate Votes  \
# 0  California               1    Audrey Denney    democrat           263096
# 1  California               1    Doug La Malfa  republican           320092
# 2  California              10      Jeff Denham  republican           211910
# 3  California              10      Josh Harder    democrat           231890
# 4  California              11  John Fitzgerald  republican           142624
#
#    Total Votes
# 0       583188
# 1       583188
# 2       443800
# 3       443800
# 4       551362

# %%
# Create a new column with the % of the vote that the candidate received
house_df["Candidate Percent"] = house_df["Candidate Votes"] / house_df["Total Votes"]
house_df.head()
# Out:
#         State District Number        Candidate       Party  Candidate Votes  \
# 0  California               1    Audrey Denney    democrat           263096
# 1  California               1    Doug La Malfa  republican           320092
# 2  California              10      Jeff Denham  republican           211910
# 3  California              10      Josh Harder    democrat           231890
# 4  California              11  John Fitzgerald  republican           142624
#
#    Total Votes  Candidate Percent
# 0       583188           0.451134
# 1       583188           0.548866
# 2       443800           0.477490
# 3       443800           0.522510
# 4       551362           0.258676

# %%
# Create new column with unique identifier for state-district
house_df["Congressional District"] = house_df["State"] + " " + house_df["District Number"]
house_df.head()
# Out:
#         State District Number        Candidate       Party  Candidate Votes  \
# 0  California               1    Audrey Denney    democrat           263096
# 1  California               1    Doug La Malfa  republican           320092
# 2  California              10      Jeff Denham  republican           211910
# 3  California              10      Josh Harder    democrat           231890
# 4  California              11  John Fitzgerald  republican           142624
#
#    Total Votes  Candidate Percent Congressional District
# 0       583188           0.451134           California 1
# 1       583188           0.548866           California 1
# 2       443800           0.477490          California 10
# 3       443800           0.522510          California 10
# 4       551362           0.258676          California 11

# %%
# DISCUSS WITH GROUP - EXCLUDE OTHER??? Otherwise, would have to sum up all "other" for each district...

# Change all parties other than democrat and republican to "other"
# house_df.loc[(house_df["Party"] != "republican") & (house_df["Party"] != "democrat"), "Party"] = "other"
# house_df.loc[house_df["Party"] == "other"]

# %%
# Create a new DataFrame looking at Republican candidates only
republican_df = house_df.loc[house_df["Party"] == "republican"]
republican_df = republican_df.rename(columns={"Candidate": "Republican Candidate", 
                                              "Candidate Votes": "Republican Votes",
                                              "Candidate Percent": "Republican Percent"})
republican_df = republican_df.drop(columns="Party")
republican_df.head()
# Out:
#          State District Number Republican Candidate  Republican Votes  \
# 1   California               1        Doug La Malfa            320092
# 2   California              10          Jeff Denham            211910
# 4   California              11      John Fitzgerald            142624
# 6   California              12          Lisa Remmer             83560
# 10  California              14      Cristina Osmena            110878
#
#     Total Votes  Republican Percent Congressional District
# 1        583188            0.548866           California 1
# 2        443800            0.477490          California 10
# 4        551362            0.258676          California 11
# 6        634144            0.131768          California 12
# 10       533646            0.207774          California 14

# %%
# Create a new DataFrame looking at Democrat candidates only
democrat_df = house_df.loc[house_df["Party"] == "democrat"]
democrat_df = democrat_df.rename(columns={"Candidate": "Democrat Candidate", 
                                          "Candidate Votes": "Democrat Votes",
                                          "Candidate Percent": "Democrat Percent"})
democrat_df = democrat_df.drop(columns="Party")
democrat_df.head()
# Out:
#         State District Number Democrat Candidate  Democrat Votes  Total Votes  \
# 0  California               1      Audrey Denney          263096       583188
# 3  California              10        Josh Harder          231890       443800
# 5  California              11    Mark DeSaulnier          408738       551362
# 7  California              12       Nancy Pelosi          550584       634144
# 8  California              13        Barbara Lee          521160       589674
#
#    Democrat Percent Congressional District
# 0          0.451134           California 1
# 3          0.522510          California 10
# 5          0.741324          California 11
# 7          0.868232          California 12
# 8          0.883810          California 13

# %%
# DISCUSS WITH GROUP - EXLCUDE OTHER???

# Create a new DataFrame looking at Other candidates only
#other_df = house_df.loc[house_df["Party"] == "other"]
#other_df = other_df.rename(columns={"Candidate": "Other Candidate", 
                                    "Candidate Votes": "Other Votes",
                                    "Candidate Percent": "Other Percent"})
#other_df = other_df.drop(columns="Party")
#other_df.head()

# %%
# Merge the DataFrames

# Start with Republican + Democrat DataFrames and clean up columns
house_party_df = pd.merge(republican_df, democrat_df, on="Congressional District")
house_party_df = house_party_df.rename(columns={"State_x": "State", "District Number_x": "District Number", 
                                                "Total Votes_x": "Total Votes"})
house_party_df = house_party_df.drop(columns=["State_y", "District Number_y", "Total Votes_y"])


# DISCUSS WITH GROUP - EXCLUDE OTHER???
# Add Other DataFrame to merged DataFrame and clean up columns
#house_party_df = pd.merge(house_party_df, other_df, on="Congressional District")
#house_party_df = house_party_df.rename(columns={"State_x": "State", "District Number_x": "District Number", 
#                                                "Total Votes_x": "Total Votes"})
#house_party_df = house_party_df.drop(columns=["State_y", "District Number_y", "Total Votes_y"])

house_party_df.head()
# Out:
#         State District Number Republican Candidate  Republican Votes  \
# 0  California               1        Doug La Malfa            320092
# 1  California              10          Jeff Denham            211910
# 2  California              11      John Fitzgerald            142624
# 3  California              12          Lisa Remmer             83560
# 4  California              14      Cristina Osmena            110878
#
#    Total Votes  Republican Percent Congressional District Democrat Candidate  \
# 0       583188            0.548866           California 1      Audrey Denney
# 1       443800            0.477490          California 10        Josh Harder
# 2       551362            0.258676          California 11    Mark DeSaulnier
# 3       634144            0.131768          California 12       Nancy Pelosi
# 4       533646            0.207774          California 14      Jackie Speier
#
#    Democrat Votes  Democrat Percent
# 0          263096          0.451134
# 1          231890          0.522510
# 2          408738          0.741324
# 3          550584          0.868232
# 4          422768          0.792226

# %%
# Create a column showing the winner

# If Republicans won the most votes, winner = "republican"
house_party_df.loc[(house_party_df["Republican Votes"] > house_party_df["Democrat Votes"]), "Winner"] = "republican"

# If Democrats won the most votes, winner = "democrat"
house_party_df.loc[(house_party_df["Democrat Votes"] > house_party_df["Republican Votes"]), "Winner"] = "democrat"

house_party_df.head()
# Out:
#         State District Number Republican Candidate  Republican Votes  \
# 0  California               1        Doug La Malfa            320092
# 1  California              10          Jeff Denham            211910
# 2  California              11      John Fitzgerald            142624
# 3  California              12          Lisa Remmer             83560
# 4  California              14      Cristina Osmena            110878
#
#    Total Votes  Republican Percent Congressional District Democrat Candidate  \
# 0       583188            0.548866           California 1      Audrey Denney
# 1       443800            0.477490          California 10        Josh Harder
# 2       551362            0.258676          California 11    Mark DeSaulnier
# 3       634144            0.131768          California 12       Nancy Pelosi
# 4       533646            0.207774          California 14      Jackie Speier
#
#    Democrat Votes  Democrat Percent      Winner
# 0          263096          0.451134  republican
# 1          231890          0.522510    democrat
# 2          408738          0.741324    democrat
# 3          550584          0.868232    democrat
# 4          422768          0.792226    democrat

# %%
# Reorder columns
house_party_df = house_party_df[["Congressional District", "State", "District Number", "Total Votes", "Republican Candidate", 
                                "Republican Votes", "Republican Percent", "Democrat Candidate", "Democrat Votes",
                                "Democrat Percent", "Winner"]]
house_party_df.head()
# Out:
#   Congressional District       State District Number  Total Votes  \
# 0           California 1  California               1       583188
# 1          California 10  California              10       443800
# 2          California 11  California              11       551362
# 3          California 12  California              12       634144
# 4          California 14  California              14       533646
#
#   Republican Candidate  Republican Votes  Republican Percent  \
# 0        Doug La Malfa            320092            0.548866
# 1          Jeff Denham            211910            0.477490
# 2      John Fitzgerald            142624            0.258676
# 3          Lisa Remmer             83560            0.131768
# 4      Cristina Osmena            110878            0.207774
#
#   Democrat Candidate  Democrat Votes  Democrat Percent      Winner
# 0      Audrey Denney          263096          0.451134  republican
# 1        Josh Harder          231890          0.522510    democrat
# 2    Mark DeSaulnier          408738          0.741324    democrat
# 3       Nancy Pelosi          550584          0.868232    democrat
# 4      Jackie Speier          422768          0.792226    democrat
